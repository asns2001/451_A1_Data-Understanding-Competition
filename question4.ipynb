# %%
import pandas as pd
from haversine import haversine, Unit
import matplotlib.pyplot as plt
import folium
import json
import numpy as np
from shapely.geometry import Point, MultiPoint
from shapely.ops import nearest_points
from shapely.geometry import Point, shape
from shapely.geometry.polygon import Polygon

# %% [markdown]
# # Load the data

# %%
# bus stops in Kingston
bus_stops = pd.read_csv("./bus-stops.csv")

# municipal voting locations
voting = pd.read_csv("./municipal-voting-locations.csv")

# census income data
census = pd.read_csv("./neighbourhood-census-profiles-income-occupation-education.csv")

# %% [markdown]
# # Perform Preprocessing

# %% [markdown]
# ## Bus Stops

# %%
# for the bus stops, all that is needed is the coordinate locations and the IDs (to help with debugging), the rest can be dropped
bus_stops = bus_stops.drop(columns=["Code", "Name", "Description", "Zone ID", "URL", "Location Type", "Parent Station ID", "Timezone", "Wheelchair Boarding"])

# %%
# coordinates should be lists of floats or dictionary, not strings
print(bus_stops["Coordinates"][0])
# Out:
# 44.25722, -76.57395

# %%
# now we can properly check for null values and see that there are none!
bus_stops.isnull().any()
# Out:
# ID             False
# Coordinates    False
# dtype: bool

# %%
# finally for bus stops, since each coordinate is a string, let's fix that
bus_stops["Coordinates"] = bus_stops["Coordinates"].apply(lambda bus_stop_coords: [float(coord) for coord in bus_stop_coords.split(",")])

# %% [markdown]
# ## Census

# %%
# since each coordinate is a string and our GeoJSON data is a string, we will conver them to a list of floats and a dictionary respectively
census["geo_point_2d"] = census["geo_point_2d"].apply(lambda parking_coords: [float(coord) for coord in parking_coords.split(",")])
census["GeoJSON"] = census["GeoJSON"].apply(lambda parking_coords: json.loads(parking_coords))

# %% [markdown]
# ## Voting

# %%
voting.isnull().any()
# Out:
# Election Year                False
# Electoral District Name      False
# Electoral District Number    False
# Voting Location Name         False
# Voting Location Address      False
# Voting Location Type         False
# Voting Location Opens        False
# Voting Location Number        True
# Voting Location Closes       False
# GeoJSON                      False
# geo_point_2d                 False
# dtype: bool

# %%
# since each coordinate is a string and our GeoJSON data is a string, we will conver them to a list of floats and a dictionary respectively
voting["geo_point_2d"] = voting["geo_point_2d"].apply(lambda parking_coords: [float(coord) for coord in parking_coords.split(",")])
voting["GeoJSON"] = voting["GeoJSON"].apply(lambda parking_coords: json.loads(parking_coords))

# %%
# compute how many bus stops are within 250m of a parking lot
counts = []
for index, voting_row in voting.iterrows():
    count = 0
    for index_2, bus_stop in bus_stops.iterrows():
        dist = haversine(voting_row["geo_point_2d"], bus_stop["Coordinates"], unit=Unit.METERS)
        if dist < 250:
            count += 1    
    
    counts.append(count)

# %%
# update the voting dataframe to include the number of bus stops nearby
voting["stops_nearby"] = counts

# %%
# map the parking locations with red if there's no bus stops nearby and green otherwise
m = folium.Map(location=[44.255457210079605, -76.57542256523625	], zoom_start=13, tiles="OpenStreetMap")

for index, row in voting.iterrows():
    if row["stops_nearby"] == 0:
        color =  "red" 
    else:
        color = "green"
    folium.Marker(location=row['geo_point_2d'], icon=folium.Icon(color=color),).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc9856db22ba7ec7360b0e883331a39e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc9856db22ba7ec7360b0e883331a39e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc9856db22ba7ec7360b0e883331a39e = L.map(
#                 &quot;map_dc9856db22ba7ec7360b0e883331a39e&quot;,
#                 {
#                     center: [44.255457210079605, -76.57542256523625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fd92ee67a56669e401a0b3487b5fa16 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3fd92ee67a56669e401a0b3487b5fa16.addTo(map_dc9856db22ba7ec7360b0e883331a39e);
#
#
#             var marker_e1b54deb99c0fcce2a89a65cc1d86e5c = L.marker(
#                 [44.249589231076, -76.5847962599758],
#                 {}
#             ).addTo(map_dc9856db22ba7ec7360b0e883331a39e);
#
#
#             var icon_10f7c60e891e6371205b46302a0964fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1b54deb99c0fcce2a89a65cc1d86e5c.setIcon(icon_10f7c60e891e6371205b46302a0964fa);
#
#
#             var marker_36bf4c47efc423001a9ca9a65cf0d0cf = L.marker(
#                 [44.261037375306, -76.49003832636264],
#                 {}
#             ).addTo(map_dc9856db22ba7ec7360b0e883331a39e);
#
#
#             var icon_fd91e5be7938d3d3538b91a9f374e9aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_36bf4c47efc423001a9ca9a65cf0d0cf.setIcon(icon_fd91e5be7938d3d3538b91a9f374e9aa);
#
#
#             var marker_385c203471e94c8d0a894cea2d586443 = L.marker(
#                 [44.229241764908735, -76.49072103593282],
#                 {}
#             ).addTo(map_dc9856db22ba7ec7360b0e883331a39e);
#
#
#             var icon_24e83d3ded95b8507688d00abea8764f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_385c203471e94c8d0a894cea2d586443.setIcon(icon_24e83d3ded95b8507688d00abea8764f);
#
#
#             var marker_3d21f1eedbd9c89f489f38ac31ff3518 = L.marker(
#                 [44.319851925397025, -76.50220837435101],
#                 {}
#             ).addTo(map_dc9856db22ba7ec7360b0e883331a39e);
#
#
#             var icon_d47f9f711c60cc17e07dd65bd33e976d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3d21f1eedbd9c89f489f38ac31ff3518.setIcon(icon_d47f9f711c60cc17e07dd65bd33e976d);
#
#
#             var marker_0aa68a0bca31fd6a1b4ddfc979501a6d = L.marker(
#                 [44.26517882746698, -76.48284617472493],
#                 {}
#             ).addTo(map_dc9856db22ba7ec7360b0e883331a39e);
#
#
#             var icon_35c6fb5866a2dd931430f7e7f9182d7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0aa68a0bca31fd6a1b4ddfc979501a6d.setIcon(icon_35c6fb5866a2dd931430f7e7f9182d7e);
#
#
#             var marker_9e006b60475c5eef56b5754679f9e548 = L.marker(
#                 [44.24324075901921, -76.49338921758695],
#                 {}
#             ).addTo(map_dc9856db22ba7ec7360b0e883331a39e);
#
#
#             var icon_4ee6cb54d703e860e15b9065f8a5ce6f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9e006b60475c5eef56b5754679f9e548.setIcon(icon_4ee6cb54d703e860e15b9065f8a5ce6f);
#
#
#             var marker_73c6b76312ae69d67d2a12c6fc91f22f = L.marker(
#                 [44.231552, -76.519772],
#                 {}
#             ).addTo(map_dc9856db2
